# %%
from bs4 import BeautifulSoup
import requests

whatmobile = "https://www.whatmobile.com.pk/"
source = requests.get(whatmobile).text
soup = BeautifulSoup(source,"lxml")

# print(soup.prettify())

menu = soup.find('div',class_="verticalMenu")
section = menu.find_all('section')[1]

links = []
for li in section.ul.find_all('li'):
    links.append(li.a.get("href"))

total_mobiles = 0

import csv

with open("MobileDatabase.csv","w",newline = "") as f:
    handler = csv.writer(f,delimiter = ",")
    handler.writerow(['Model Name','RAM','ROM','CPU','OS','Price'])
    
    useless_companies = [10,17,21,22,23]
    for index,link in enumerate(links[:26]):
        if index in useless_companies:
            continue
        company = whatmobile + link
        print(company)
        source = requests.get(company).text
        soup = BeautifulSoup(source,"lxml")
        try:
            mobiles = soup.find('div',class_="mobiles")
        # print(mobiles.prettify())

            models = []
            for item in mobiles.find_all('div',class_="item"):
                link = item.div.a.get("href")
                models.append(link)

            for i in models:
                source = requests.get("https://www.whatmobile.com.pk" + i).text
                try:
                    soup = BeautifulSoup(source,'lxml')

                    specs = []
                    for td in soup.find_all('td',class_='fasla RowBG1 specs-value bottom-border'):
                        specs.append(td.text)

                    model = soup.find('h1',class_='hdng3').text
                    price = soup.find('td',class_='fasla RowBG1 bottom-border-section right-border specs-subHeading')
                    price = price.strong.text


                    os = specs[0].strip()
                    cpu = specs[2].strip()
                    mem = specs[4].split(",")
                    rom = mem[0].strip()
                    ram = mem[1].strip()
                    print("Model: ",model,"\nos: ",os,"\ncpu: ",cpu,"\nram: ",ram,"\nrom:",rom,"\nPrice: ",price)
                    handler.writerow([model,ram,rom,cpu,os,price])
#                     q = input("Do you want to Add Entry? y/n: ")
#                     if q == 'y':
#                         handler.writerow([model,ram,rom,cpu,os,price])
#                     else:
#                         continue
                except:
                    print("Format Not Supported")
                    
            
        except:
            models = []
            for td in soup.find_all('td',class_='BiggerText'):
                if td.a == None:
                    continue
                else:
                    link = td.a.get('href')
                    models.append(link)
            for i in models:
                source = requests.get("https://www.whatmobile.com.pk" + i).text
                try:
                    soup = BeautifulSoup(source,'lxml')

                    specs = []
                    for td in soup.find_all('td',class_='fasla RowBG1 specs-value bottom-border'):
                        specs.append(td.text)

                    model = soup.find('h1',class_='hdng3').text
                    price = soup.find('td',class_='fasla RowBG1 bottom-border-section right-border specs-subHeading')
                    price = price.strong.text


                    os = specs[0].strip()
                    cpu = specs[2].strip()
                    mem = specs[4].split(",")
                    rom = mem[0].strip()
                    ram = mem[1].strip()
                    print("Model: ",model,"\nos: ",os,"\ncpu: ",cpu,"\nram: ",ram,"\nrom:",rom,"\nPrice: ",price)
                    handler.writerow([model,ram,rom,cpu,os,price])
#                     q = input("Do you want to Add Entry? y/n: ")
#                     if q == 'y':
#                         handler.writerow([model,ram,rom,cpu,os,price])
#                     else:
#                         continue
                except:
                    print("Format Not Supported")   
print("The End")
# Out:
# https://www.whatmobile.com.pk/Samsung_Mobiles_Prices
# Model:  Samsung Galaxy S10 Plus 512GB
# os:  Android 9.0 (Pie)
# cpu:  Octa-core (2 x 2.7 GHz Mongoose M4 + 2 x 2.3 GHz Cortex-A75 + 4 x 1.9 GHz Cortex-A55)
# ram:  8GB RAM
# rom: 512GB Built-in
# Price:  219,999
# Model:  Samsung Galaxy Note 9 512GB
# os:  Android V8.1 Oreo
# cpu:  Octa-core (4 x 2.7 GHz Mongoose M3 + 4 x 1.8 GHz Cortex-A55)
# ram:  8GB RAM
# rom: 512GB Built-in
# Price:  170,000
# Model:  Samsung Galaxy S10 Plus
# os:  Android 9.0 (Pie)
# cpu:  Octa-core (2 x 2.7 GHz Mongoose M4 + 2 x 2.3 GHz Cortex-A75 + 4 x 1.9 GHz Cortex-A55)
# ram:  8GB RAM
# rom: 128GB Built-in
# Price:  159,999
# Model:  Samsung Galaxy Note 9
# os:  Android V8.1 Oreo
# cpu:  Octa-core (4 x 2.7 GHz Mongoose M3 + 4 x 1.8 GHz Cortex-A55)
# ram:  6 GB RAM
# rom: 128 GB Built-in
# Price:  139,999
# Model:  Samsung Galaxy S10
# os:  Android 9.0 (Pie)
# cpu:  Octa-core (2 x 2.7 GHz Mongoose M4 + 2 x 2.3 GHz Cortex-A75 + 4 x 1.9 GHz Cortex-A55)
# ram:  8GB RAM
# rom: 128GB Built-in
# Price:  139,999
# Model:  Samsung Galaxy S9 Plus 128GB
# os:  Android V8.0 Oreo
# cpu:  Octa-core (4 x 2.7 GHz Mongoose M3 + 4 x 1.8 GHz Cortex-A55)
# ram:  6GB RAM
# rom: 128GB Built-in
# Price:  111,999
# Model:  Samsung Galaxy S9 Plus
# os:  Android V8.0 Oreo
# cpu:  Octa-core (4 x 2.8 GHz Mongoose M3 + 4 x 1.7 GHz Cortex-A55)
# ram:  6GB RAM
# rom: 64GB Built-in
# Price:  110,999
# Model:  Samsung Galaxy S9
# os:  Android V8.0 Oreo
# cpu:  Octa-core (4 x 2.8 GHz Mongoose M3 + 4 x 1.7 GHz Cortex-A55)
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  91,000
# Model:  Samsung Galaxy Note 8
# os:  Android v7.1.1 Nougat
# cpu:  Octa-core (4 x 2.3 GHz + 4 x 1.7 GHz)
# ram:  6GB RAM
# rom: 64/128/256GB built-in
# Price:  89,999
# Model:  Samsung Galaxy S8 Plus
# os:  Android OS, v7.0 (Nougat)
# cpu:  Octa-core (4 x 2.3 GHz + 4 x 1.7 GHz)
# ram:  4GB RAM
# rom: 64GB built-in
# Price:  84,999
# Model:  Samsung Galaxy S8
# os:  Android OS, v7.0 (Nougat)
# cpu:  Octa-core (4 x 2.3 GHz + 4 x 1.7 GHz)
# ram:  4GB RAM
# rom: 64GB built-in
# Price:  79,999
# Model:  Samsung Galaxy A9 2018
# os:  79,999/-
# cpu:  SIM1: GSM 850 / 900 / 1800 / 1900SIM2: GSM 850 / 900 / 1800 / 1900
# ram:  16M colors
# rom: Super AMOLED capacitive touchscreen
# Price:  79,999
# Model:  Samsung Galaxy A70
# os:  Android 9.0 (Pie)
# cpu:  Octa-core (2 x 2.0 GHz Kryo 460 Gold + 6 x 1.7 GHz Kryo 460 Silver)
# ram:  6GB RAM
# rom: 128GB Built-in
# Price:  67,999
# Model:  Samsung Galaxy A8 Plus 2018
# os:  Android v7.1.1 Nougat
# cpu:  Super Amoled Capacitive  Touchscreen, 16M Colors, Multitouch
# ram:  autofocus
# rom: 16 MP
# Price:  63,999
# Model:  Samsung Galaxy A50
# os:  Android 9.0 (Pie)
# cpu:  Octa-core (4 x 2.3GHz cortex A-73+ 4 x 1.7GHz Cortex-A53)
# ram:  4GB RAM
# rom: 128GB Built-in
# Price:  54,999
# https://www.whatmobile.com.pk/Huawei_Mobiles_Prices
# Model:  Huawei P30 Pro
# os:  Android 9.0 (Pie)
# cpu:  Octa-core (2 x 2.6 GHz Cortex-A76 + 2 x 1.92 GHz Cortex-A76 + 4 x 1.8 GHz Cortex-A55)
# ram:  8GB RAM
# rom: 256GB Built-in
# Price:  174,999
# Model:  Huawei Mate 20 Pro
# os:  Android 9.0 (Pie)
# cpu:  Octa-core (2 x 2.6 GHz Cortex-A76 + 2 x 1.92 GHz Cortex-A76 + 4 x 1.8 GHz Cortex-A55)
# ram:  6GB RAM
# rom: 128GB Built-in
# Price:  149,999
# Model:  Huawei P30
# os:  Android 9.0 (Pie)
# cpu:  Octa-core (2 x 2.6 GHz Cortex-A76 + 2 x 1.92 GHz Cortex-A76 + 4 x 1.8 GHz Cortex-A55)
# ram:  6GB RAM or 64/128/256GB Built-in
# rom: 128GB Built-in
# Price:  124,999
# Model:  Huawei P20 Pro
# os:  Android V8.0 Oreo
# cpu:  Octa-core (4 x 2.4 GHz Cortex-A73 + 4 x 1.8 GHz Cortex-A53)
# ram:  6GB RAM
# rom: 128GB Built-in
# Price:  99,999
# Model:  Huawei Mate 10 Pro
# os:  Android v8.0
# cpu:  Octa-core (4 x 2.4 GHz Cortex-A73 + 4 x 1.8 GHz Cortex-A53)
# ram:  4/6GB RAM
# rom: 64/128GB Built-in
# Price:  74,999
# Model:  Huawei Nova 3
# os:  Android V8.1 Oreo
# cpu:  Octa-core (4 x 2.4 GHz Cortex-A73 + 4 x 1.8 GHz Cortex-A53)
# ram:  4GB RAM
# rom: 128GB Built-in
# Price:  59,999
# Model:  Honor 9
# os:  Android OS V7.0 (Nougat)
# cpu:  Octa-core (4 x 2.4 GHz Cortex-A73 + 4 x 1.8 GHz Cortex-A53)
# ram:  6GB RAM
# rom: 128GB Built-in
# Price:  56,999
# Model:  Huawei Honor 7
# os:  Android OS, v5.0 (Lollipop), upgradable to 6.0 (Marshmallow)
# cpu:  Octa core (4 x 2.2 GHz Cortex A53 + 4 x 1.5 GHz Cortex A53)
# ram:  3GB RAM
# rom: 16GB/64GB built-in
# Price:  40,000
# Model:  Huawei P30 Lite
# os:  Android 9.0 (Pie)
# cpu:  Octa-core (4 x 2.2 GHz Cortex-A73 + 4 x 1.7 GHz Cortex-A53)
# ram:  4GB RAM
# rom: 128GB Built-in
# Price:  39,999
# Model:  Huawei Nova 3i
# os:  Android V8.1 Oreo
# cpu:  Octa-core (4 x 2.2 GHz Cortex-A73 + 4 x 1.7 GHz Cortex-A53)
# ram:  4GB RAM
# rom: 128GB Built-in
# Price:  36,999
# Model:  Huawei Y9 2019
# os:  Android V8.1 Oreo
# cpu:  Octa-core (4 x 2.2 GHz Cortex-A73 + 4 x 1.7 GHz Cortex-A53)
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  35,999
# Format Not Supported
# Model:  Huawei P20 Lite
# os:  Android V8.0 Oreo
# cpu:  Octa-core (4 x 2.36 GHz Cortex-A53 + 4 x 1.7 GHz Cortex-A53)
# ram:  4GB RAM
# rom: 64/128GB Built-in
# Price:  34,999
# Model:  Huawei Y9 Prime 2019
# os:  Android 9.0 (Pie)
# cpu:  Octa-core (4 x 2.2 GHz Cortex-A73 + 4 x 1.7 GHz Cortex-A53)
# ram:  4GB RAM
# rom: 128GB Built-in
# Price:  33,999
# Model:  Huawei P10 Lite
# os:  Android OS, v7.0 (Nougat)
# cpu:  Octa-core (4 x 2.1 GHz Cortex-A53 + 4 x 1.7 GHz Cortex-A53)
# ram:  4GB RAM
# rom: 32GB built-in
# Price:  31,999
# https://www.whatmobile.com.pk/Vivo_Mobiles_Prices
# Model:  Vivo V15 Pro
# os:  Android 9.0 (Pie)
# cpu:  Octa-core (2 x 2.0 GHz Kryo 460 Gold + 6 x 1.7 GHz Kryo 460 Silver)
# ram:  6GB RAM
# rom: 128GB Built-in
# Price:  59,999
# Model:  Vivo V11 Pro
# os:  Android V8.1 Oreo
# cpu:  Octa-core (4 x 2.2 GHz Kryo 260 + 4 x 1.8 GHz Kryo 260)
# ram:  6GB RAM
# rom: 128GB Built-in
# Price:  53,999
# Model:  Vivo V15
# os:  Android 9.0 (Pie)
# cpu:  Octa-core (4 x 2.1 GHz Cortex-A73 + 4 x 2.0 GHz Cortex-A53)
# ram:  6GB RAM
# rom: 64GB Built-in
# Price:  45,999
# Model:  Vivo V11
# os:  Android V8.1 Oreo
# cpu:  Octa-core (4 x 2.2 GHz Kryo 260 + 4 x 1.8 GHz Kryo 260)
# ram:  4GB RAM
# rom: 128GB Built-in
# Price:  43,999
# Model:  Vivo Y17
# os:  Android 9.0 Pie
# cpu:  Octa-core (4 x 2.3 GHz Cortex-A53 + 4 x 1.8 GHz Cortex-A53)
# ram:  4GB RAM
# rom: 128GB Built-in
# Price:  36,999
# Model:  Vivo Y95
# os:  Android V8.1 Oreo
# cpu:  Octa-core (2 x 1.95 GHz Cortex-A53 + 6 x 1.45 GHz Cortex A53)
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  31,999
# Model:  Vivo V9 Price in Pakistan and Specifications
# os:  Android V8.0 Oreo
# cpu:  Octa core
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  29,999
# Model:  Vivo Y15
# os:  Android 9.0 Pie
# cpu:  2.0 Ghz Octa Core Cortex-A53
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  29,999
# Model:  Vivo Y91
# os:  Android V8.1 Oreo
# cpu:  Octa-core (2 x 1.95 GHz Cortex-A53 + 6 x 1.45 GHz Cortex A53)
# ram:  3GB RAM
# rom: 64GB Built-in
# Price:  26,999
# Model:  Vivo Y93
# os:  Android V8.1 Oreo
# cpu:  Octa-core (2 x 1.95 GHz Cortex-A53 + 6 x 1.45 GHz Cortex A53)
# ram:  3GB RAM
# rom: 32GB Built-in
# Price:  24,999
# Format Not Supported
# Model:  Vivo Y91c
# os:  Android V8.1 Oreo
# cpu:  2.0 Ghz Octa Core
# ram:  2GB RAM
# rom: 32GB Built-in
# Price:  18,999
# Model:  Vivo V9 Youth Price & Specs
# os:  Android v8.1 Oreo
# cpu:  1.8 Ghz Octa Core Cortex-A53
# ram:  4GB RAM
# rom: 32GB Built-in
# Price:  N/A
# Model:  Vivo Y53 Price & Specs
# os:  Android v6.0 Marshmallow
# cpu:  1.4 GHz Quad Core
# ram:  2GB RAM
# rom: 16GB Built-in
# Price:  Discontinued
# Model:  Vivo Y55s Price & Specs
# os:  Android v6.0 Marshmallow
# cpu:  1.4 Ghz Quad Core Cortex-A53
# ram:  3GB RAM
# rom: 16GB Built-in
# Price:  Discontinued
# https://www.whatmobile.com.pk/Honor_Mobiles_Prices
# Model:  Honor 10
# os:  Android v8.1 Oreo
# cpu:  Octa-core (4 x 2.36 GHz Cortex-A73 + 4 x 1.8 GHz Cortex-A53)
# ram:  4GB RAM
# rom: 128GB Built-in
# Price:  59,999
# Model:  Honor 9
# os:  Android OS V7.0 (Nougat)
# cpu:  Octa-core (4 x 2.4 GHz Cortex-A73 + 4 x 1.8 GHz Cortex-A53)
# ram:  6GB RAM
# rom: 128GB Built-in
# Price:  56,999
# Model:  Honor Play
# os:  Android V8.1 Oreo
# cpu:  Octa-core (4 x 2.4 GHz Cortex-A73 + 4 x 1.8 GHz Cortex-A53)
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  41,999
# Model:  Honor 8X
# os:  Android V8.1 Oreo
# cpu:  Octa-core (4 x 2.2 GHz Cortex-A73 + 4 x 1.7 GHz Cortex-A53)
# ram:  4GB RAM
# rom: 128GB Built-in
# Price:  34,999
# Model:  Honor 7X 4GB
# os:  Android v7.0 Nougat
# cpu:  Octa-core (4 x 2.36 GHz Cortex-A53 + 4 x 1.7 GHz Cortex-A53)
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  31,999
# Model:  Honor 10 Lite
# os:  Android 9.0 (Pie)
# cpu:  Octa-core (4 x 2.2 GHz Cortex-A73 + 4 x 1.7 GHz Cortex-A53)
# ram:  3GB RAM
# rom: 64GB Built-in
# Price:  28,499
# Model:  Honor 9 Lite
# os:  Android V8.0 Oreo
# cpu:  2.36 GHz Octa (4 x 2.36 GHz Core Cortex-A53 & 4 x 1.7 GHz Core Cortex-A53)
# ram:  3GB RAM
# rom: 32GB Built-in
# Price:  26,999
# Model:  Honor 7X
# os:  Android v7.0 Nougat
# cpu:  Octa-core (4 x 2.36 GHz Cortex-A53 + 4 x 1.7 GHz Cortex-A53)
# ram:  3GB RAM
# rom: 32GB Built-in
# Price:  25,999
# Model:  Honor 7C
# os:  Android V8.0 Oreo
# cpu:  1.8 GHz Octa-Core Cortex-A53
# ram:  3GB RAM or 64GB Built-in
# rom: 32GB Built-in
# Price:  24,999
# Model:  Honor 8C
# os:  Android V8.1 Oreo
# cpu:  Octa-core (4 x 1.8 GHz Kryo 250 Gold + 4 x 1.8 GHz Kryo 250 Silver)
# ram:  3GB RAM
# rom: 32/64GB Built-in
# Price:  23,999
# Model:  Honor 5C Pro
# os:  Android v7.0 Nougat
# cpu:  Octa Core (4 x 2.36 GHz Core Cortex-A53 & 4 x 1.7 GHz Core Cortex-A53)
# ram:  3GB RAM
# rom: 32GB Built-in
# Price:  18,999
# Model:  Honor 7A
# os:  Android V8.0 Oreo
# cpu:  Octa-core (4 x 1.4 GHz Cortex-A53 + 4 x 1.1 GHz Cortex A53)
# ram:  2GB RAM
# rom: 16GB Built-in
# Price:  18,999
# Model:  Honor 8S
# os:  Android 9.0 (Pie)
# cpu:  2.0 Ghz Quad Core
# ram:  2GB RAM
# rom: 32GB Built-in
# Price:  18,999
# Model:  Honor 7S
# os:  Android V8.1 Oreo
# cpu:  Quad-Core (4 x 1.5 Ghz Quad Core Cortex-A53)
# ram:  2GB RAM
# rom: 16GB Built-in
# Price:  17,699
# Model:  Honor 8X 64GB Price & Specs
# os:  Android V8.1 Oreo
# cpu:  Octa-core (4 x 2.2 GHz Cortex-A73 + 4 x 1.7 GHz Cortex-A53)
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  Discontinued
# https://www.whatmobile.com.pk/Oppo_Mobiles_Prices
# Model:  Oppo Find X
# os:  Android V8.1 Oreo
# cpu:  Octa-core (4 x 2.8 GHz Kryo 385 Gold + 4 x 1.7 GHz Kryo 385 Silver)
# ram:  8GB RAM
# rom: 256GB Built-in
# Price:  129,999
# Model:  Oppo Reno 10X Zoom
# os:  Android 9.0 (Pie)
# cpu:  Octa-core (1 x 2.84 GHz Kryo 485 + 3 x 2.42 GHz Kryo 485 + 4 x 1.8 GHz Kryo 485)
# ram:  8GB RAM
# rom: 256GB Built-in
# Price:  109,999
# Model:  Oppo R17 Pro
# os:  Android V8.1 Oreo
# cpu:  Octa-core (2 x 2.2 GHz 360 Gold + 6 x 1.7 GHz Kryo 360 Silver)
# ram:  6/8GB RAM
# rom: 128GB Built-in
# Price:  79,999
# Model:  Oppo Reno
# os:  Android 9.0 (Pie)
# cpu:  Octa-core (2 x 2.2 GHz Kryo 360 Gold + 6 x 1.7 GHz Kryo 360 Silver)
# ram:  8GB RAM
# rom: 128GB Built-in
# Price:  69,999
# Model:  Oppo F11 Pro
# os:  Android Color OS 6
# cpu:  Octa-core (4 x 2.1 GHz Cortex-A73 + 4 x 2.0 GHz Cortex-A53)
# ram:  6GB RAM
# rom: 128GB Built-in
# Price:  54,999
# Model:  Oppo F7 128GB
# os:  Android v8.0 Oreo
# cpu:  Octa-core (4 x 2.0 GHz Cortex-A73 + 4 x 2.0 GHz Cortex-A53)
# ram:  6GB RAM
# rom: 128GB Built-in
# Price:  50,000
# Model:  Oppo F9 6GB
# os:  Android V8.1 Oreo
# cpu:  Octa-core (4 x 2.0 GHz Cortex-A73 + 4 x 2.0 GHz Cortex-A53)
# ram:  6GB RAM
# rom: 64GB Built-in
# Price:  49,999
# Model:  Realme 2 Pro
# os:  Android V8.1 Oreo
# cpu:  Octa-core (4 x 2.0 GHz Kryo 260 + 4 x 1.8 GHz Kryo 260)
# ram:  8GB RAM
# rom: 128GB Built-in
# Price:  46,999
# Model:  Oppo F11 Pro 64GB
# os:  Android Color OS 6
# cpu:  Octa-core (4 x 2.1 GHz Cortex-A73 + 4 x 2.0 GHz Cortex-A53)
# ram:  6GB RAM
# rom: 64GB Built-in
# Price:  45,999
# Model:  Oppo F11
# os:  Android ColorOS 6
# cpu:  Octa-core (4 x 2.1 GHz Cortex-A73 + 4 x 2.0 GHz Cortex-A53)
# ram:  4GB RAM or 128GB Built-in
# rom: 64GB Built-in
# Price:  39,999
# Model:  Oppo F5 6GB
# os:  Android v7.0 Nougat
# cpu:  IPS LCD Capacitive Touchscreen, 16M Colors, Multitouch
# ram:  autofocus
# rom: 16 MP
# Price:  39,899
# Model:  Oppo F9
# os:  Android V8.1 Oreo
# cpu:  Octa-core (4 x 2.0 GHz Cortex-A73 + 4 x 2.0 GHz Cortex-A53)
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  36,999
# Model:  Oppo F7 Price in Pakistan and Specifications
# os:  Android V8.0 Oreo
# cpu:  Octa-core (4 x 2.0 GHz Cortex-A73 + 4 x 2.0 GHz Cortex-A53)
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  33,000
# Model:  Oppo A7
# os:  Android V8.1 Oreo
# cpu:  1.8 GHz Octa-Core Cortex-A53
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  31,999
# Model:  Oppo A5
# os:  Android V8.1 Oreo
# cpu:  1.8 Ghz Octa Core Cortex-A53
# ram:  4GB RAM
# rom: 32GB Built-in
# Price:  29,999
# https://www.whatmobile.com.pk/Realme_Mobiles_Prices
# Model:  Realme 2 Pro
# os:  Android V8.1 Oreo
# cpu:  Octa-core (4 x 2.0 GHz Kryo 260 + 4 x 1.8 GHz Kryo 260)
# ram:  8GB RAM
# rom: 128GB Built-in
# Price:  46,999
# Model:  Realme 3 Pro 6GB
# os:  Android 9.0 (Pie)
# cpu:  Octa-core (2 x 2.2 GHz Kryo 360 Gold + 6 x 1.7 GHz Kryo 360 Silver)
# ram:  6GB RAM
# rom: 128GB Built-in
# Price:  39,999
# Model:  Realme 3 Pro
# os:  Android 9.0 (Pie)
# cpu:  Octa-core (2 x 2.2 GHz Kryo 360 Gold + 6 x 1.7 GHz Kryo 360 Silver)
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  35,499
# Model:  Realme 3 4GB
# os:  Android 9.0 (Pie)
# cpu:  Octa-core (4 x 2.1 GHz Cortex-A73 + 4 x 2.0 GHz Cortex-A53)
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  24,999
# Model:  Realme 3
# os:  Android 9.0 (Pie)
# cpu:  Octa-core (4 x 2.1 GHz Cortex-A73 + 4 x 2.0 GHz Cortex-A53)
# ram:  3GB RAM
# rom: 32GB Built-in
# Price:  22,999
# Model:  Realme C2
# os:  Android 9.0 (Pie)
# cpu:  2.0 GHz Octa-Core Cortex-A53
# ram:  2/3GB RAM
# rom: 16/32GB Built-in
# Price:  20,999
# Model:  Realme C1
# os:  Android V8.1 Oreo
# cpu:  1.8 GHz Octa Core Cortex-A53
# ram:  2GB RAM
# rom: 16GB Built-in
# Price:  16,999
# https://www.whatmobile.com.pk/Nokia_Mobiles_Prices
# Model:  Nokia 8.1
# os:  Android 9.0 (Pie); Android One
# cpu:  Octa-core (2 x 2.2 GHz 360 Gold + 6 x 1.7 GHz Kryo 360 Silver)
# ram:  4/6GB RAM
# rom: 64/128GB Built-in
# Price:  39,899
# Model:  Nokia 7 Plus
# os:  Android One
# cpu:  Octa-core (4 x 2.2 GHz Kryo 260 + 4 x 1.8 GHz Kryo 260)
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  36,800
# Model:  Nokia 8
# os:  Android v7.1.1 Nougat upgradable to Android 8.0 (Oreo)
# cpu:  Octa-core (4 x 2.5 GHz Kryo + 4 x 1.8 GHz Kryo)
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  35,990
# Model:  Nokia 7.1
# os:  Android V8.1 Oreo upgradable to Android 9.0 (Pie); Android One
# cpu:  1.8 GHz Octa Core Kryo 260
# ram:  3/4GB RAM
# rom: 32/64GB Built-in
# Price:  33,899
# Model:  Nokia 6.1 Plus
# os:  Android V8.1 Oreo; Android One
# cpu:  1.8 GHz Octa Core Kryo 260
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  28,799
# Model:  Nokia 6 2018
# os:  Android One
# cpu:  2.2 Ghz Octa Core Cortex-A53
# ram:  3GB RAM
# rom: 32/64GB Built-in
# Price:  27,800
# Model:  Nokia 3.2 32GB
# os:  Android 9.0 (Pie); Android One
# cpu:  1.8 Ghz Octa Core Cortex-A53
# ram:  3GB RAM
# rom: 32GB Built-in
# Price:  25,500
# Model:  Nokia 3.1 Plus
# os:  Android V8.0 Oreo ; Android One
# cpu:  2.0 GHz Octa-Core Cortex A-53
# ram:  3GB RAM
# rom: 32GB Built-in
# Price:  23,990
# Model:  Nokia 5.1 Plus
# os:  Android V8.1 Oreo; Android One
# cpu:  Octa-core (4 x 2.0 GHz Cortex-A73 + 4 x 2.0 GHz Cortex-A53)
# ram:  3GB RAM
# rom: 32GB Built-in
# Price:  22,899
# Format Not Supported
# Model:  Nokia 3.1
# os:  Android V8.0 Oreo; (Android One)
# cpu:  Octa-core (4 x 1.5 GHz Cortex-A53 + 4 x 1.0 GHz Cortex-A53)
# ram:  2GB RAM
# rom: 16GB Built-in
# Price:  19,899
# Model:  Nokia 2.2
# os:  Android 9.0 (Pie); Android One
# cpu:  2.0 Ghz Quad Core Cortex-A53
# ram:  3GB RAM
# rom: 32GB Built-in
# Price:  18,699
# Model:  Nokia 3.2 Price in Pakistan and Specifications
# os:  Android 9.0 (Pie); Android One
# cpu:  1.8 Ghz Octa Core Cortex-A53
# ram:  2GB RAM
# rom: 16GB Built-in
# Price:  18,299
# Model:  Nokia 5
# os:  Android OS 7.1 (Nougat)
# cpu:  1.4 GHZ Octa-Core Cortex-A53
# ram:  2GB RAM
# rom: 16GB built-in
# Price:  17,650
# Model:  Nokia 3
# os:  Android OS 7.0 (Nougat)
# cpu:  1.4 Quad-Core Cortex-A53
# ram:  2GB RAM
# rom: 16GB built-in
# Price:  16,400
# https://www.whatmobile.com.pk/Xiaomi_Mobiles_Prices
# Model:  Xiaomi Mi 8
# os:  Android V8.1 Oreo
# cpu:  Octa-core (4 x 2.8 GHz Kryo 385 Gold + 4 x 1.8 GHz Kryo 385 Silver)
# ram:  6GB RAM
# rom: 64/128/256GB Built-in
# Price:  64,999
# Model:  Xiaomi Mi Mix 2
# os:  Android v7.1.1 Nougat
# cpu:  Octa Core (4 x 2.45 GHz Kryo + 4 x 1.9 GHz Kryo)
# ram:  6GB RAM
# rom: 64GB Built-in
# Price:  52,999
# Model:  Xiaomi Pocophone F1
# os:  Android V8.1 Oreo
# cpu:  Octa-core (4 x 2.8 GHz Kryo 385 Gold + 4 x 1.8 GHz Kryo 385 Silver)
# ram:  6GB RAM
# rom: 128GB Built-in
# Price:  51,999
# Model:  Xiaomi Mi 6
# os:  Android v7.0 Nougat
# cpu:  Octa-core (4 x 2.45 GHz Kryo + 4 x 1.9 GHz Kryo)
# ram:  6GB RAM
# rom: 64/128GB Built-in
# Price:  43,999
# Model:  Xiaomi Mi A2
# os:  Android 8.1 (Oreo); Android One
# cpu:  Octa-core (4 x 2.2 GHz Kryo 260 + 4 x 1.8 GHz Kryo 260)
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  36,999
# Model:  Xiaomi Redmi Note 7
# os:  Android 9.0 (Pie)
# cpu:  Octa-core (4 x 2.2 GHz Kryo 260 + 4 x 1.8 GHz Kryo 260)
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  35,999
# Model:  Xiaomi Redmi Note 6 Pro 4GB
# os:  Android V8.1 Oreo
# cpu:  1.8 GHz Octa Core Kryo 260
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  34,999
# Model:  Xiaomi Mi 8 Lite
# os:  Android V8.1 Oreo
# cpu:  Octa-core (4 x 2.2 GHz Kryo 260 + 4 x 1.8 GHz Kryo 260)
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  33,499
# Model:  Xiaomi Redmi Note 5 Pro
# os:  Android v7.1.2 Nougat
# cpu:  1.8 GHz Octa Core Kryo 260
# ram:  4GB RAM (LPDDR4X RAM)
# rom: 64GB Built-in
# Price:  31,999
# Model:  Xiaomi Mi A1
# os:  Android One
# cpu:  2Ghz Octa Core Cortex-A53
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  29,900
# Model:  Xiaomi Mi Max 2
# os:  Android OS, v7.0 (Nougat)
# cpu:  2 Ghz Octa Core Cortex-A53
# ram:  4GB RAM
# rom: 64/128GB built-in
# Price:  28,999
# Model:  Xiaomi Redmi S2 4GB
# os:  Android v8.1 Oreo
# cpu:  2.0 Ghz Octa Core Cortex A-53
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  28,999
# Model:  Xiaomi Redmi Note 6 Pro
# os:  Android V8.1 Oreo
# cpu:  1.8 GHz Octa Core Kryo 260
# ram:  3GB RAM
# rom: 32GB Built-in
# Price:  27,999
# Model:  Xiaomi Redmi 5 Plus 4GB
# os:  Android v7.1.2 Nougat
# cpu:  2 Ghz Octa Core Cortex-A53
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  26,900
# Model:  Xiaomi Redmi 7
# os:  Android 9.0 (Pie)
# cpu:  Octa-core (4 x 1.8 GHz Kryo 250 Gold + 4 x 1.8 GHz Kryo 250 Silver)
# ram:  3GB RAM
# rom: 32GB Built-in
# Price:  25,999
# https://www.whatmobile.com.pk/Infinix_Mobiles_Prices
# Model:  Infinix Note 5 Stylus
# os:  Android One
# cpu:  2.0 GHz Octa Core
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  37,899
# Model:  Infinix Note 5
# os:  Android One
# cpu:  2.0 Ghz Octa Core
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  32,999
# Model:  Infinix Zero 5
# os:  Android v7.1.2 Nougat
# cpu:  2.6 Ghz Octa Core
# ram:  6GB RAM
# rom: 64GB Built-in
# Price:  29,999
# Model:  Infinix Zero 4 Plus
# os:  Android OS V6.0 (Marshmallow)
# cpu:  2.1 GHz Deca-Core
# ram:  4GB RAM
# rom: 64GB built-in
# Price:  26,499
# Model:  Infinix Note 4 Pro
# os:  Android v7.0 Nougat
# cpu:  1.3 Ghz Octa Core Cortex A53, 64 bit
# ram:  3GB RAM
# rom: 32GB Built-in
# Price:  26,400
# Model:  Infinix Hot S3 4GB
# os:  Android V8.0 Oreo
# cpu:  1.4 Ghz Octa Core
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  25,999
# Model:  Infinix Hot S3X 4GB
# os:  Android V8.1 Oreo
# cpu:  1.4 Ghz Octa Core
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  23,999
# Model:  Infinix S4
# os:  Android 9.0 (Pie)
# cpu:  2.0 Ghz Octa Core Cortex-A53
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  22,999
# Model:  Infinix Note 3 4G
# os:  Androis OS v6.0 (Marshmallow)
# cpu:  1.3 GHZ Octa-Core
# ram:  2GB RAM
# rom: 16GB built-in
# Price:  20,599
# Model:  Infinix Hot 7 Pro
# os:  Android 9.0 (Pie)
# cpu:  1.8 Ghz Quad Core Cortex-A53
# ram:  2/3/6GB RAM
# rom: 32/64GB Built-in
# Price:  19,999
# Model:  Infinix Hot S3X
# os:  Android V8.1 Oreo
# cpu:  1.4 Ghz Octa Core
# ram:  3GB RAM
# rom: 32GB Built-in
# Price:  19,600
# Model:  Infinix Smart 2 32GB
# os:  Android V8.1 Oreo
# cpu:  1.5 Ghz Quad Core
# ram:  3GB RAM
# rom: 32GB Built-in
# Price:  19,500
# Format Not Supported
# Format Not Supported
# Model:  Infinix Note 4
# os:  Android v7.0 Nougat
# cpu:  1.3 Ghz Octa Core
# ram:  3GB RAM
# rom: 32GB Built-in
# Price:  18,999
# https://www.whatmobile.com.pk/Apple_Mobiles_Prices
# Model:  Apple iPhone XS Max
# os:  IOS 12
# cpu:  Hexa Core
# ram:  4GB RAM
# rom: 64/256/512GB Built-in
# Price:  167,999
# Model:  Apple iPhone XS
# os:  IOS 12
# cpu:  Hexa Core
# ram:  4GB RAM
# rom: 64/256/512GB Built-in
# Price:  156,999
# Model:  Apple iPhone7 Plus 128GB
# os:  iOS 10.01 upgradable to iOS 10.0.2
# cpu:  Quad-core 2.34 GHz (2 x Hurricane & 2 x Zephyr)
# ram:  3GB RAM
# rom: 128GB built-in
# Price:  144,999
# Model:  Apple iPhone X
# os:  IOS 11
# cpu:  Hexa Core (2 x Monsoon + 4 x Mistral)
# ram:  3GB RAM
# rom: 64GB Built-in
# Price:  129,999
# Model:  Apple iPhone XR
# os:  IOS 12
# cpu:  Hexa Core
# ram:  3GB RAM
# rom: 64 Built-in
# Price:  117,999
# Model:  Apple iphone 8 Plus
# os:  iOS 11
# cpu:  Hexa Core
# ram:  3GB RAM
# rom: 64GB Built-in
# Price:  111,999
# Model:  Apple iPhone 7 Plus 256GB
# os:  iOS 10.01 upgradable to iOS 10.0.2
# cpu:  Quad-core 2.34 GHz (2 x Hurricane & 2 x Zephyr)
# ram:  3GB RAM
# rom: 256GB built-in
# Price:  109,999
# Model:  Apple iPhone 7 Plus
# os:  iOS 10.01 upgradable to iOS 10.0.2
# cpu:  Quad-core 2.34 GHz (2 x Hurricane & 2 x Zephyr)
# ram:  3GB RAM
# rom: 32GB built-in
# Price:  100,900
# Model:  Apple iphone 8
# os:  IOS 11
# cpu:  Hexa Core (2x Monsoon + 4x Mistral)
# ram:  2GB RAM
# rom: 64/256GB Built-in
# Price:  97,999
# Model:  Apple iphone 7 256GB
# os:  iOS 10
# cpu:  Quad-core 2.34 GHz (2 x Hurricane & 2 x Zephyr)
# ram:  2GB RAM
# rom: 256GB built-in
# Price:  90,999
# Model:  Apple iphone 7 128GB
# os:  iOS 10
# cpu:  Quad-core 2.34 GHz (2 x Hurricane & 2 x Zephyr)
# ram:  2GB RAM
# rom: 128GB built-in
# Price:  83,999
# Model:  Apple iphone 6s Plus 128GB
# os:  iOS 9, upgradable to iOS 9.3.3 & planned upgrade to iOS 10
# cpu:  1.84 GHz Dual-Core Twister
# ram:  2GB RAM
# rom: 128GB built-in
# Price:  82,000
# Model:  Apple iphone 7
# os:  iOS 10
# cpu:  Quad-core 2.34 GHz (2 x Hurricane & 2 x Zephyr)
# ram:  2GB RAM
# rom: 32GB built-in
# Price:  74,999
# Model:  Apple iphone 6s Plus 64GB
# os:  iOS 9, upgradable to iOS 9.3.3 & planned upgrade to iOS 10
# cpu:  1.84 GHz Dual-Core Twister
# ram:  2GB RAM
# rom: 64GB built-in
# Price:  72,999
# Format Not Supported
# https://www.whatmobile.com.pk/Qmobile_Mobiles_Prices
# Model:  QMobile Noir E8
# os:  Android OS, v5.1 (Lollipop)
# cpu:  2 GHz Octa-Core Cortex-A53
# ram:  3GB RAM
# rom: 64GB built-in
# Price:  27,500
# Format Not Supported
# Model:  QMobile Noir A1
# os:  Android v7.0 Nougat
# cpu:  2 Ghz Octa Core
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  21,500
# Format Not Supported
# Model:  QMobile Noir M6
# os:  Android v6.0 Marshmallow
# cpu:  2 Ghz Octa Core
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  20,500
# Model:  QMobile Noir Z9
# os:  Android OS, v5.0.2 (Lollipop)
# cpu:  1.2 GHz Quad-Core Cortex-A53
# ram:  2GB RAM
# rom: 16GB built-in
# Price:  19,500
# Model:  QMobile Noir Z9 Plus
# os:  Android V5.1 (Lollipop
# cpu:  HD Amoled Display
# ram:  autofocus
# rom: 13 MP
# Price:  19,500
# Model:  QMobile Phantom P1 Pro
# os:  Android 8.1 Oreo (Go edition)
# cpu:  IPS LCD Capacitive Touchscreen, 16M colors, Multitouch
# ram:  autofocus
# rom: 13 MP
# Price:  18,500
# Model:  QMobile Noir J7 Pro
# os:  Android v6.0 Marshmallow
# cpu:  1.5 Ghz Quad Core
# ram:  3GB RAM
# rom: 32GB Built-in
# Price:  17,999
# Model:  QMobile QInfinity Prime
# os:  Android V8.1 Oreo
# cpu:  IPS LCD Capacitive Touchscreen, 16M Colors, Multitouch
# ram:  autofocus
# rom: 13 MP
# Price:  17,999
# Model:  QMobile Noir Z8 Plus
# os:  Android 4.4 (Kit KAt)
# cpu:  1.2GHz Quad-core
# ram:  2GB RAM
# rom: 16GB built-in
# Price:  17,990
# Format Not Supported
# Model:  QMobile Noir A1 Lite
# os:  Android v7.0 Nougat
# cpu:  IPS LCD Capacitive Touchscreen, 16M Colors
# ram:  autofocus
# rom: 13 MP
# Price:  17,500
# Model:  QMobile Q Infinity
# os:  Android v7.0 Nougat
# cpu:  1.4 Ghz Quad Core
# ram:  3GB RAM
# rom: 32GB Built-in
# Price:  16,999
# Model:  QMobile Phantom P1
# os:  Android 8.1 Oreo (Go edition)
# cpu:  IPS LCD Capacitive Touchscreen, 16M colors, Multitouch
# ram:  autofocus
# rom: 13 MP
# Price:  16,999
# https://www.whatmobile.com.pk/Lenovo_Mobiles_Prices
# Model:  Lenovo Moto Z
# os:  Android 6.0.1 (Marshmallow), 7.1.1 (Nougat), planned upgrade to Android 8.0 (Oreo)
# cpu:  Quad-core (2 x 1.8 GHz Kryo + 2 x 1.6 GHz Kryo)
# ram:  4GB RAM
# rom: 32/64GB built-in
# Price:  66,900
# Model:  Lenovo Vibe Z2
# os:  Android OS, v4.4 (KitKat)
# cpu:  1.2 GHz Quad-Core Cortex-A53
# ram:  2GB RAM
# rom: 32GB built-in
# Price:  51,000
# Model:  Lenovo Vibe P2
# os:  Android OS v6.0 (Marshmallow), upgradable to 7.0 (Nougat)
# cpu:  2 GHz Octa-core Cortex-A53
# ram:  4GB RAM
# rom: 64GB built-in
# Price:  36,900
# Model:  Lenovo Vibe S1
# os:  Android OS, v5.0 (Lollipop)
# cpu:  1.7 GHz Octa-Core Cortex-A53
# ram:  3GB RAM
# rom: 32GB built-in
# Price:  36,500
# Model:  Lenovo S5
# os:  Android V8.0 Oreo
# cpu:  2.0 Ghz Octa Core cortex-A5
# ram:  3GB RAM or 64/128GB Built-in
# rom: 32GB Built-in
# Price:  34,999
# Model:  Lenovo Vibe P1
# os:  Android OS, v5.1 (Lollipop)
# cpu:  1.5 GHz Quad-Core Cortex-A53, 1.0 GHz Quad-Core Cortex-A53
# ram:  2GB RAM
# rom: 32GB built-in
# Price:  34,000
# Model:  Lenovo K5 Note
# os:  Android OS, v5.1 (Lollipop)
# cpu:  1.8 GHz Octa-Core Cortex-A53
# ram:  3GB RAM
# rom: 32GB built-in
# Price:  31,499
# Model:  Lenovo Vibe X2
# os:  Android OS, v4.4 (KitKat)
# cpu:  2.0 GHz Quad-Core Cortex-A17 +  1.7 GHz Quad-Core Cortex-A7
# ram:  2GB RAM
# rom: 32GB built-in
# Price:  30,600
# Model:  Lenovo A7010
# os:  Android OS, v5.1 (Lollipop)
# cpu:  1.5 GHz Octa-Core Cortex-A53
# ram:  2GB RAM
# rom: 8/16/32GB built-in
# Price:  29,900
# Model:  Lenovo S90
# os:  Android OS, v4.4.4 (KitKat)
# cpu:  1.2 GHz Quad-Core Cortex-A53
# ram:  1/2GB RAM
# rom: 16/32GB built-in
# Price:  26,900
# Model:  Lenovo Vibe S1 Lite
# os:  Android OS, v5.0 (Lollipop)
# cpu:  1.3 GHz Octa-Core Cortex-A53
# ram:  2GB RAM
# rom: 16GB built-in
# Price:  26,000
# Model:  Lenovo K6 Note
# os:  Android OS, v6.0 (Marshmallow)
# cpu:  1.4 GHz Octa-Core Cortex-A53
# ram:  3GB RAM
# rom: 32GB built-in
# Price:  25,900
# Model:  Lenovo Zuk Z1
# os:  Android OS, v5.1.1 (Lollipop)
# cpu:  2.5 GHz Quad-Core Krait 400
# ram:  3GB RAM
# rom: 64GB built-in
# Price:  23,999
# Model:  Lenovo S60
# os:  Android OS, v4.4 (KitKat)
# cpu:  1.2 GHz Quad-Core Cortex-A53
# ram:  2GB RAM
# rom: 8GB built-in
# Price:  22,700
# Model:  Lenovo P70
# os:  Android OS, v4.4 (KitKat)
# cpu:  1.7 GHz Octa-Core Cortex-A53
# ram:  2GB RAM
# rom: 16GB built-in
# Price:  22,500
# https://www.whatmobile.com.pk/Sony_Mobiles_Prices
# Format Not Supported
# Format Not Supported
# Model:  Sony Xperia XZ1
# os:  Android V8.0 Oreo
# cpu:  Octa-core (4 x 2.35 GHz Kryo + 4 x 1.9 GHz Kryo)
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  63,999
# Format Not Supported
# Format Not Supported
# Model:  Sony Xperia XA2 Ultra
# os:  Android V8.0 Oreo
# cpu:  2.2 Ghz Octa Core Cortex-A53
# ram:  4GB RAM
# rom: 32/64GB Built-in
# Price:  48,999
# Format Not Supported
# Format Not Supported
# Format Not Supported
# Model:  Sony Xperia XZ
# os:  Android OS, v6.0.1 (Marshmallow) upgradable to v7.0 (Nougat)
# cpu:  Quad-core (2 x 2.15 GHz Kryo & 2 x 1.6 GHz Kryo)
# ram:  3GB RAM
# rom: 64GB Built-in
# Price:  41,999
# Format Not Supported
# Format Not Supported
# Format Not Supported
# Format Not Supported
# Model:  Sony Xperia XA1 Plus
# os:  Android v7.0 Nougat upgradable to Android 8.0 (Oreo)
# cpu:  Octa-core (4 x 2.3 GHz Cortex-A53 + 4 x 1.6 GHz Cortex-A53)
# ram:  3/4GB RAM
# rom: 32GB Built-in
# Price:  32,999
# https://www.whatmobile.com.pk/LG_Mobiles_Prices
# Model:  LG V30 Plus
# os:  Android v7.1.1 Nougat
# cpu:  Qualcomm Snapdragon 835
# ram:  4GB RAM
# rom: 128GB Built-in
# Price:  80,999
# Model:  LG V30
# os:  Android v7.1.2 Nougat
# cpu:  Octa-core (4 x 2.45 GHz Kryo + 4 x 1.9 GHz Kryo)
# ram:  4GB RAM or 128GB Built-in
# rom: 64GB Built-in
# Price:  74,999
# Model:  LG G6
# os:  Android OS, v7.0 (Nougat)
# cpu:  Quad-core (2 x 2.35 GHz Kryo + 2 x 1.6 GHz Kryo)
# ram:  4GB RAM
# rom: 32/64/128GB Built-in
# Price:  55,900
# Model:  LG Q8
# os:  Android v7.0 Nougat
# cpu:  Quad-core (2 x 2.15 GHz Kryo + 2 x 1.6 GHz Kryo)
# ram:  4GB RAM
# rom: 32GB Built-in
# Price:  53,999
# Model:  LG Optimus G
# os:  Android OS, v4.1.2 (Jelly Bean)
# cpu:  Quad-core 1.5 GHz Krait
# ram:  2GB RAM
# rom: 32GB built-in
# Price:  52,800
# Model:  LG Ray
# os:  Android OS, v5.1 (Lollipop)
# cpu:  1.4 GHz Octa-Core Cortex-A7
# ram:  1GB RAM
# rom: 16GB built-in
# Price:  45,000
# Model:  LG Stylus 2 Plus
# os:  Android OS, v6.0 (Marshmallow)
# cpu:  1.2 GHz Quad-Core Cortex-A53
# ram:  2GB RAM
# rom: 16/32GB built-in
# Price:  45,000
# Model:  LG G Vista 2
# os:  Android OS, (Lollipop)
# cpu:  Octa-Core processor
# ram:  2GB RAM
# rom: 16GB built-in
# Price:  43,500
# Model:  LG G Pro 2
# os:  Android OS, v4.4.2 (KitKat)
# cpu:  2.26 GHZ Quad-core Krait 400
# ram:  3GB RAM
# rom: 16/32GB built-in
# Price:  41,500
# Model:  LG V10
# os:  Android OS, v5.1 (Lollipop)
# cpu:  1.44 GHz Quad-Core Cortex-A53, 1.82 GHz Quad-Core Cortex-A57
# ram:  4GB RAM
# rom: 64GB built-in
# Price:  41,500
# Model:  LG X venture
# os:  Android v7.0 Nougat
# cpu:  1.4 Ghz Octa Core Cortex-A53
# ram:  2GB RAM
# rom: 32GB Built-in
# Price:  37,999
# Model:  LG X Cam
# os:  Android 6.0 (Marshmallow)
# cpu:  1.14 GHz Octa-core Cortex-A53
# ram:  2GB RAM
# rom: 16GB built-in
# Price:  35,000
# Model:  LG Nexus 4
# os:  Android OS, v4.2 (Jelly Bean), upgradable to v4.2.1 (Jelly Bean)
# cpu:  Quad-core 1.5 GHz Krait
# ram:  2GB RAM
# rom: 8/16 GB built-in
# Price:  33,000
# Model:  LG Nexus 5
# os:  Android OS, v5.0 (Lolipop), upgradable to v5.1.1 (Lollipop)
# cpu:  2.3 GHz Quad-Core Krait
# ram:  2GB RAM
# rom: 16/32GB built-in
# Price:  32,000
# Model:  LG G4
# os:  Android OS, v5.1 (Lollipop)
# cpu:  1.8 GHz Quad-Core Cortex-A57, 1.44 GHz Quad-Core Cortex-A53
# ram:  3GB RAM
# rom: 32GB built-in
# Price:  31,799
# https://www.whatmobile.com.pk/Meizu_Mobiles_Prices
# Model:  Meizu Pro 7 Plus
# os:  Android v7.0 Nougat
# cpu:  Deca-core (2 x 2.6 GHz Cortex A73 + 4 x 1.9 GHz Cortex A35 + 4 x 2.2 GHz Cortex A53)
# ram:  6GB RAM
# rom: 64/128GB Built-in
# Price:  59,999
# Model:  Meizu Pro 7
# os:  Android v7.0 Nougat
# cpu:  Octa-core (4 x 1.6 GHz Cortex A53 + 4 x 1.6 GHz Cortex-A35)
# ram:  4GB RAM
# rom: 64/128GB Built-in
# Price:  45,999
# Model:  Meizu MX6
# os:  Android v6.0 Marshmallow
# cpu:  Deca-core (2 x 2.3 GHz Cortex-A72, 4 x 1.9 GHz Cortex-A53, 4 x 1.4 GHz Cortex-A53)
# ram:  3/4GB RAM
# rom: 32GB Built-in
# Price:  31,500
# Model:  Meizu M6 Note
# os:  Android v7.1.2 Nougat
# cpu:  Octa-core 2.0 GHz Cortex-A53
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  29,999
# Model:  Meizu M6T
# os:  Android v7.0 Nougat
# cpu:  Octa-core (4 x 1.5 GHz Cortex-A53 + 4 x 1.0 GHz Cortex-A53)
# ram:  3GB RAM
# rom: 32GB Built-in
# Price:  24,000
# Model:  Meizu M3 Note
# os:  Android V5.0.1 Lollipop
# cpu:  Octa-core (4 x 1.8 GHz Cortex-A53 + 4 x 1.0 GHz Cortex-A53)
# ram:  2GB RAM or 32GB Built-in
# rom: 16GB Built-in
# Price:  19,500
# Model:  Meizu M6
# os:  Android v7.0 Nougat
# cpu:  1.5 Ghz Octa Core Cortex-A53
# ram:  3GB RAM
# rom: 32GB Built-in
# Price:  17,999
# Model:  Meizu M5
# os:  Android v6.0 Marshmallow
# cpu:  1.5 GHz Octa-Core Cortex-A5
# ram:  2GB RAM
# rom: 16GB Built-in
# Price:  15,100
# Model:  Meizu C9
# os:  Android V8.0 Oreo
# cpu:  1.3Ghz Quad Core
# ram:  2GB RAM
# rom: 16GB Built-in
# Price:  14,000
# Model:  Meizu M6s
# os:  Android v7.0 Nougat
# cpu:  Hexa-core (4 x 1.6 GHz Cortex-A53 + 2 x 2.0 GHz Cortex-A73)
# ram:  3GB RAM
# rom: 32/64GB Built-in
# Price:  Coming Soon
# Model:  Meizu M16s Price & Specs
# os:  Android V8.1 Oreo
# cpu:  Octa Core
# ram:  8GB RAM
# rom: 128/256GB Built-in
# Price:  Coming Soon
# Model:  Meizu C9 Pro Price & Specs
# os:  Android V8.0 Oreo
# cpu:  1.3Ghz Quad Core
# ram:  3GB RAM
# rom: 32GB Built-in
# Price:  Coming Soon
# Model:  Meizu 16s Pro Price & Specs
# os:  Android 9.0 (Pie)
# cpu:  Octa-core (1 x2 .84 GHz Kryo 485 + 3 x 2.41 GHz Kryo 485 + 4 x 1.78 GHz Kryo 485)
# ram:  8GB RAM
# rom: 256GB Built-in
# Price:  Coming Soon
# Model:  Meizu M15 Lite Price & Specs
# os:  Android v7.1.2 Nougat
# cpu:  2.2Ghz Octa Core Cortex-A53
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  Coming Soon
# Model:  Meizu M15 Plus Price & Specs
# os:  Android v7.1.2 Nougat
# cpu:  Octa-core (4 x 2.5 GHz Mongoose M2 + 4 x 1.7 GHz Cortex-A53)
# ram:  6GB RAM
# rom: 64/128GB Built-in
# Price:  Coming Soon
# https://www.whatmobile.com.pk/OnePlus_Mobiles_Prices
# Model:  OnePlus 6
# os:  Android V8.1 Oreo
# cpu:  Octa-core (4 x 2.8 GHz Kryo 385 Gold & 4 x 1.7 GHz Kryo 385 Silver)
# ram:  6GB RAM or 256 Built-in
# rom: 64/128GB Built-in
# Price:  78,000
# Model:  OnePlus 5T
# os:  Android v7.1.1 Nougat
# cpu:  Octa-core (4 x 2.45 GHz Kryo + 4 x 1.9 GHz Kryo)
# ram:  6/8GB RAM
# rom: 64/128GB Built-in
# Price:  65,000
# Model:  OnePlus 5
# os:  Android v7.1.1 Nougat
# cpu:  Octa-core (4 x 2.45 GHz Kryo + 4 x 1.9 GHz Kryo)
# ram:  8GB RAM
# rom: 128GB Built-in
# Price:  64,999
# Model:  OnePlus 6T
# os:  Android 9.0 (Pie)
# cpu:  Octa-core (4 x 2.8 GHz Kryo 385 Gold + 4 x 1.7 GHz Kryo 385 Silver)
# ram:  6/8GB RAM
# rom: 128/256GB Built-in
# Price:  Coming Soon
# Model:  OnePlus 7 Price & Specs
# os:  Android 9.0 (Pie)
# cpu:  Octa-core (1 x 2.84 GHz Kryo 485 + 3 x 2.42 GHz Kryo 485 + 4 x 1.80 GHz Kryo 485)
# ram:  6/8GB RAM
# rom: 128/256GB Built-in
# Price:  Coming Soon
# Model:  OnePlus 7 Pro Price & Specs
# os:  Android 9.0 (Pie)
# cpu:  Octa-core (1 x 2.84 GHz Kryo 485 + 3 x 2.42 GHz Kryo 485 + 4 x 1.80 GHz Kryo 485)
# ram:  6GB RAM or 256GB Built-in
# rom: 128GB Built-in
# Price:  Coming Soon
# https://www.whatmobile.com.pk/Alcatel_Mobiles_Prices
# Model:  Alcatel Idol 4s
# os:  Android OS, v6.0.1 (Marshmallow)
# cpu:  1.8 GHz Quad-Core Cortex-A72, 1.4 GHz Quad-Core Cortex-A53
# ram:  3GB RAM
# rom: 32GB built-in
# Price:  49,500
# Model:  Alcatel Idol 4
# os:  Android OS, v6.0.1 (Marshmallow)
# cpu:  1.7 GHz Quad-Core Cortex-A53, 1.2 GHz Quad-Core Cortex-A53
# ram:  3GB RAM
# rom: 16GB built-in
# Price:  28,750
# Model:  Alcatel Idol 3
# os:  Android OS, v5.0.2 (Lollipop)
# cpu:  1.5 GHz Quad-Core Cortex-A53, 1.0 GHz Quad-Core Cortex-A53
# ram:  2GB RAM
# rom: 16GB built-in
# Price:  24,500
# Model:  Alcatel X1
# os:  Android V5.1 (Lollipop)
# cpu:  1.4 GHZ Quad-Core Cortex-A53, 1.0 GHz Quad-Core Cortex-A53
# ram:  2GB RAM
# rom: 16GB built-in
# Price:  19,999
# Model:  Alcatel Pop 4S
# os:  Android OS, v6.0 (Marshmallow)
# cpu:  Octa-Core (1.8 GHz + 1.0 GHz)
# ram:  2GB RAM
# rom: 16GB built-in
# Price:  13,999
# Model:  Alcatel Tablet Pixi4 LTE
# os:  Android Os V6.0 (Marshmallow)
# cpu:  IPS Display
# ram:  autofocus
# rom: 8 MP
# Price:  13,900
# Model:  Alcatel Pop Star 4G
# os:  Android OS, v5.0 (Lollipop)
# cpu:  1.3 GHZ Quad-Core
# ram:  1GB RAM
# rom: 8GB built-in
# Price:  13,750
# Model:  Alcatel Pop 4
# os:  Android OS, v6.0 (Marshmallow)
# cpu:  1.1 GHz Quad-Core Cortex-A7
# ram:  1GB RAM
# rom: 8GB built-in
# Price:  13,700
# Model:  Alcatel Pop Up
# os:  Android OS, v5.0 (Lollipop)
# cpu:  1.4 GHz Octa-Core
# ram:  2GB RAM
# rom: 16GB built-in
# Price:  12,999
# Model:  Alcatel Pixi 4 Power Plus
# os:  Android Os V6.0 (Marshmallow)
# cpu:  HD IPS Display
# ram:  autofocus
# rom: 13 MP
# Price:  12,750
# Model:  Alcatel Pop Star
# os:  Android OS, v5.0 (Lollipop)
# cpu:  1.3 GHZ Quad-Core
# ram:  1GB RAM
# rom: 8GB built-in
# Price:  11,500
# Model:  Alcatel Pixi 4 6
# os:  Android OS 5.0 (Lollipop)
# cpu:  IPS LCD capacitive touchscreen, 16M colors, Multitouch up to 5 fingers
# ram:  autofocus
# rom: 8 MP
# Price:  10,000
# Model:  Alcatel Pop 4 PLus
# os:  Android OS, v6.0 (Marshmallow)
# cpu:  1.1 GHz Quad-Core Cortex-A7
# ram:  1.5GB RAM
# rom: 16GB built-in
# Price:  9,999
# Model:  Alcatel Tablet Pixi 4
# os:  Android Os V6.0 (Marshmallow)
# cpu:  High Quality Display
# ram:  autofocus
# rom: 5 MP
# Price:  9,999
# Model:  Alcatel Pixi 4 5
# os:  Android OS, v6.0 (Marshmallow)
# cpu:  1.3 GHz Quad-Core
# ram:  1GB RAM
# rom: 8GB built-in
# Price:  9,000
# https://www.whatmobile.com.pk/HTC_Mobiles_Prices
# Model:  HTC U12 Plus
# os:  Android V8.1 Oreo
# cpu:  Octa-core (4 x 2.6 GHz Kryo 385 Gold + 4 x 1.7 GHz Kryo 385 Silver)
# ram:  6GB RAM
# rom: 64/128GB Built-in
# Price:  112,999
# Model:  HTC U11 Plus
# os:  Android V8.0 Oreo
# cpu:  Octa-core (4 x 2.45 GHz Kryo + 4 x 1.9 GHz Kryo)
# ram:  4/6GB RAM
# rom: 64/128GB Built-in
# Price:  80,799
# Model:  HTC U 11
# os:  Android v7.0 Nougat
# cpu:  Octa-core (4 x 2.45 GHz Kryo + 4 x 1.9 GHz Kryo)
# ram:  4/6GB RAM
# rom: 64/128GB Built-in
# Price:  67,700
# Model:  HTC One A9
# os:  Android OS, v6.0 (Marshmallow)
# cpu:  1.5 GHZ Octa-Core Cortex-A53
# ram:  3GB RAM
# rom: 32GB built-in
# Price:  51,999
# Model:  HTC One M10
# os:  Android 6.0.1 (Marshmallow)
# cpu:  Qualcomm MSM8996 Snapdragon 820
# ram:  4GB RAM
# rom: 32GB built-in
# Price:  51,500
# Model:  HTC 10
# os:  Android OS, v6.0.1 (Marshmallow)
# cpu:  2.15 GHz Quad-Core Kryo, 1.6 GHz Quad-Core Kryo
# ram:  4GB RAM
# rom: 32/64GB built-in
# Price:  51,500
# Model:  HTC One E8
# os:  Android OS, v4.4.2 (KitKat)
# cpu:  2.5 GHz Quad-Core Krait 400
# ram:  2GB RAM
# rom: 16GB built-in
# Price:  50,000
# Model:  HTC One M9
# os:  Android OS, v5.0.1 (Lollipop)
# cpu:  1.5 GHz Quad-core Cortex-A53 + 2 GHz Quad-core Cortex-A57
# ram:  3GB RAM
# rom: 32GB built-in
# Price:  47,900
# Model:  HTC One
# os:  Android OS, v4.1.2 (Jelly Bean), upgradable to v4.2.2 (Jelly Bean)
# cpu:  Quad-core 1.7 GHz Krait 300
# ram:  2GB RAM
# rom: 32/64GB built-in
# Price:  42,000
# Model:  HTC Butterfly S
# os:  Android OS
# cpu:  Quad-core 1.9 GHz Krait 300
# ram:  2GB RAM
# rom: 16GB built-in
# Price:  42,000
# Model:  HTC U Ultra
# os:  Android OS, v7.0 (Nougat)
# cpu:  Quad-core (2 x 2.15 GHz Kryo + 2 x 1.6 GHz Kryo))
# ram:  4GB RAM
# rom: 64/128GB built-in
# Price:  39,999
# Model:  HTC One X9
# os:  Android 5.0 (Lollipop)
# cpu:  IPS display
# ram:  LED Flash
# rom: 13 MP
# Price:  37,500
# Model:  HTC Desire 610
# os:  Android OS, v4.2.2 (Jelly Bean)
# cpu:  Quad-core 1.2 GHz
# ram:  1GB RAM
# rom: 8GB built-in
# Price:  33,000
# Model:  HTC Desire 600
# os:  Android OS, v4.1.2 (Jelly Bean)
# cpu:  Quad-core 1.2 GHz Cortex-A5
# ram:  1GB RAM
# rom: 8GB built-in
# Price:  30,000
# Model:  HTC One Mini
# os:  Android OS, v4.2.2 (Jelly Bean)
# cpu:  Dual-core 1.4 GHz Krait 300
# ram:  1GB RAM
# rom: 16GB built-in
# Price:  27,499
# https://www.whatmobile.com.pk/Microsoft_Mobiles_Prices
# Model:  Microsoft Lumia 430
# os:  Microsoft Windows Phone 8.1, planned upgrade to Windows 10
# cpu:  1.2 GHz Dual-Core Cortex-A7
# ram:  1GB RAM
# rom: 8GB built-in
# Price:  5,450
# Model:  Microsoft Lumia 535 Price & Specs
# os:  Microsoft Windows Phone 8.1
# cpu:  1.2 GHz Quad-core Cortex-A7
# ram:  1GB RAM
# rom: 8GB built-in
# Price:  Discontinued
# Model:  Microsoft Lumia 535 Dual Sim Price & Specs
# os:  Microsoft Windows Phone 8.1
# cpu:  1.2 GHz Quad-core Cortex-A7
# ram:  1GB RAM
# rom: 8GB built-in
# Price:  Discontinued
# Model:  Microsoft Lumia 435 Price & Specs
# os:  Microsoft Windows Phone 8.1
# cpu:  1.2GHz Dual-Core Cortex-A7/b>
# ram:  1GB RAM
# rom: 8GB built-in
# Price:  Discontinued
# Model:  Microsoft Lumia 435 Dual Sim Price & Specs
# os:  Microsoft Windows Phone 8.1
# cpu:  1.2GHz Dual-Core Cortex-A7
# ram:  1GB RAM
# rom: 4GB built-in
# Price:  Discontinued
# Model:  Microsoft Lumia 532 Price & Specs
# os:  Microsoft Windows Phone 8.1
# cpu:  1.2 GHz Quad-Core Cortex-A7
# ram:  1GB RAM
# rom: 8GB built-in
# Price:  Discontinued
# Model:  Microsoft Lumia 640 Dual SIM Price & Specs
# os:  Microsoft Windows Phone 8.1 with Lumia Denim
# cpu:  1.2 GHz Quad-Core Cortex-A7
# ram:  1GB RAM
# rom: 8GB built-in
# Price:  Discontinued
# Model:  Microsoft Lumia 640 XL Price & Specs
# os:  Microsoft Windows Phone 8.1 with Lumia Denim
# cpu:  1.2 GHz Quad-Core Cortex-A7
# ram:  1GB RAM
# rom: 8GB built-in
# Price:  Discontinued
# Model:  Microsoft Lumia 540 Price & Specs
# os:  Microsoft Windows Phone 8.1 with Lumia Denim
# cpu:  1.2 GHz Quad-Core Cortex-A7
# ram:  1GB RAM
# rom: 8GB built-in
# Price:  Discontinued
# Model:  Microsoft Lumia 940 XL Price & Specs
# os:  Microsoft Windows 10
# cpu:  1.5 GHz Quad-Core Cortex-A53, 2 GHz Quad-Core Cortex-A57
# ram:  3GB RAM
# rom: 32GB built-in
# Price:  Discontinued
# Model:  Microsoft Lumia 940 Price & Specs
# os:  Microsoft Windows 10
# cpu:  1.82 GHz Dual-Core Cortex-A57, 1.44 GHz Quad-Core Cortex-A53
# ram:  3GB RAM
# rom: 32GB built-in
# Price:  Discontinued
# Model:  Microsoft Lumia 950 Price & Specs
# os:  Microsoft Windows 10
# cpu:  1.82 GHz Dual-Core Cortex-A57, 1.44 GHz Quad-Core Cortex-A53
# ram:  3GB RAM
# rom: 32GB built-in
# Price:  Discontinued
# Model:  Microsoft Lumia 950 XL Price & Specs
# os:  Microsoft Windows 10
# cpu:  1.5 GHz Quad-Core Cortex-A53, 2 GHz Quad-Core Cortex-A57
# ram:  3GB RAM
# rom: 32GB built-in
# Price:  Discontinued
# Model:  Microsoft Lumia 550 Price & Specs
# os:  Microsoft Windows 10
# cpu:  1.1 GHz Octa-Core Cortex-A7
# ram:  1GB RAM
# rom: 8GB built-in
# Price:  Discontinued
# Model:  Microsoft Lumia 850 Price & Specs
# os:  Microsoft Windows 10
# cpu:  IPS LCD capacitive touchscreen, 16M colors, Multitouch
# ram:  autofocus
# rom: 10 MP
# Price:  Discontinued
# https://www.whatmobile.com.pk/Motorola_Mobiles_Prices
# Model:  Motorola Moto Z Play
# os:  Android 6.0.1 (Marshmallow), 7.1.1 (Nougat), planned upgrade to Android 8.0 (Oreo)
# cpu:  2.0 GHZ Octa-Core Cortex A53
# ram:  3GB RAM
# rom: 32GB built-in
# Price:  43,900
# Model:  Motorola Moto G6 Plus
# os:  Android v7.1.1 Nougat
# cpu:  2.2 Ghz Octa Core Cortex-A53
# ram:  4/6GB RAM
# rom: 64/128GB Built-in
# Price:  42,000
# Model:  Motorola Moto X Style
# os:  Android OS, v5.1.1 (Lollipop), planned upgrade to v6.0 (Marshmallow)
# cpu:  1.8 GHz Dual-Core Cortex-A57, 1.44 GHz Quad-Core Cortex-A53
# ram:  3GB RAM
# rom: 16/32/64GB built-in
# Price:  37,500
# Model:  Motorola Moto G6
# os:  Android v7.1.1 Nougat
# cpu:  1.8 Ghz Octa Core Cortex-A53
# ram:  3/4GB RAM
# rom: 32/64GB Built-in
# Price:  36,499
# Model:  Motorola Moto G5S Plus
# os:  Android v7.1 Nougat
# cpu:  IPS LCD capacitive Touchscreen, 16M Colors
# ram:  autofocus
# rom: Dual13 MP
# Price:  28,000
# Model:  Motorola Moto E5 Plus
# os:  Android v8.0 Oreo
# cpu:  Quad Core 1.4GHz Cortex A53
# ram:  3/2GB RAM
# rom: 32GB/16 Built-in
# Price:  27,000
# Model:  Motorola Moto M
# os:  Android OS, v6.0.1 (Marshmallow)
# cpu:  1.95 GHz Octa-Core Cortex-A53
# ram:  3GB RAM
# rom: 32GB built-in
# Price:  25,400
# Model:  Motorola Moto E5
# os:  Android V8.0 Oreo
# cpu:  1.4 Ghz Quad Core Cortex-A53
# ram:  2GB RAM
# rom: 16GB Built-in
# Price:  22,500
# Model:  Motorola Moto E4 Plus
# os:  Android v7.0 Nougat
# cpu:  1.3 Ghz Quad Core
# ram:  3GB RAM
# rom: 16/32GB Built-in
# Price:  19,999
# Model:  Motorola Moto E4
# os:  Android v7.0 Nougat
# cpu:  1.3 Ghz Quad Core Cortex-A53
# ram:  2GB RAM
# rom: 16GB Built-in
# Price:  14,999
# Model:  Motorola Moto C Plus
# os:  Android v7.0 Nougat
# cpu:  1.3 Ghz Quad Core Cortex-A53
# ram:  2GB RAM
# rom: 16GB Built-in
# Price:  13,999
# Model:  Motorola Moto X Force Price & Specs
# os:  Android OS, v5.1.1 (Lollipop) upgradable to V6.0 ((Marshmallow)
# cpu:  1.5 GHz Quad-Core Cortex-A53, 2 GHz Quad-Core Cortex-A57
# ram:  3GB RAM
# rom: 32/64GB built-in
# Price:  N/A
# Model:  Motorola Moto E3 Power Price & Specs
# os:  Android OS, v6.0.1 (Marshmallow)
# cpu:  1.0 GHz Quad-Core Cortex-A53
# ram:  2GB RAM
# rom: 16GB built-in
# Price:  N/A
# Model:  Motorola Moto G5 Plus Price & Specs
# os:  Android OS, v7.0 (Nougat)
# cpu:  2.0 GHZ octa-core Cortex-A53
# ram:  2GB RAM
# rom: 64GB built-in
# Price:  N/A
# Format Not Supported
# https://www.whatmobile.com.pk/BlackBerry_Mobiles_Prices
# Model:  BlackBerry Key 2
# os:  Android V8.1 Oreo
# cpu:  Octa-core (4 x 2.2 GHz Kryo 260 + 4 x 1.8 GHz Kryo 260)
# ram:  4/6GB RAM
# rom: 64/128GB Built-in
# Price:  102,999
# Model:  BlackBerry Evolve
# os:  Android V8.1 Oreo
# cpu:  1.8 Ghz Octa Core Cortex-A53
# ram:  4GB RAM
# rom: 64GB Built-in
# Price:  57,999
# Model:  BlackBerry Motion
# os:  Android v7.1.1 Nougat
# cpu:  2 Ghz Octa Core Cortex-A53
# ram:  4GB RAM
# rom: 32GB Built-in
# Price:  52,249
# Model:  BlackBerry DTEK50
# os:  Android OS, v6.0 (Marshmallow)
# cpu:  1.5 GHz Quad-Core Cortex-A53, 1.2 GHz Quad-Core Cortex-A53
# ram:  3GB RAM
# rom: 16GB built-in
# Price:  45,000
# Model:  BlackBerry Priv
# os:  Android OS, v5.1.1 (Lollipop), upgradable to v6.0.1 (Marshmallow)
# cpu:  1.8 GHz Dual-Core Cortex-A57, 1.44 GHz Quad-Core Cortex-A53
# ram:  3GB RAM
# rom: 32GB built-in
# Price:  44,000
# Model:  BlackBerry Aurora
# os:  Android 7.0 (Nougat)
# cpu:  1.4 GHz Quad-Core Cortex-A53
# ram:  4GB RAM
# rom: 32GB built-in
# Price:  24,999
# Model:  BlackBerry Torch 9810 Price & Specs
# os:  BlackBerry OS 7.0
# cpu:  8GB built-in, 768MB RAM
# ram:  UMA (carrier-dependent)
# rom: Wi-Fi 802.11 b/g/n
# Price:  Discontinued
# Format Not Supported
# Format Not Supported
# Format Not Supported
# Format Not Supported
# Model:  BlackBerry Bold 9650 Price & Specs
# os:  BlackBerry OS
# cpu:  TFT, 65K colors
# ram:  2048x1536 pixels
# rom: 3.15MP
# Price:  Discontinued
# Format Not Supported
# Model:  BlackBerry Bold 9700 Price & Specs
# os:  BlackBerry OS 5.0
# cpu:  TFT, 65K colors
# ram:  2048x1536 pixels
# rom: 3.15MP
# Price:  Discontinued
# Model:  BlackBerry Bold 9780 Price & Specs
# os:  BlackBerry OS 6.0
# cpu:  TFT, 65K colors
# ram:  2592x1944 pixels
# rom: 5MP
# Price:  Discontinued
# https://www.whatmobile.com.pk/Voice_Mobiles_Prices
# Format Not Supported
# Format Not Supported
# Format Not Supported
# Format Not Supported
# Format Not Supported
# Model:  Voice V850 Price & Specs
# os:  Android OS, v2.3.6 (Gingerbread)
# cpu:  3.2MP
# ram:  Speakerphone
# rom: 3.5mm audio jack
# Price:  Discontinued
# Format Not Supported
# Model:  Voice Xtreme V70 Price & Specs
# os:  Android OS, Jelly Bean 4.2
# cpu:  IPS QHD Touchscreen, 16M colors, Multitouch
# ram:  autofocus
# rom: 12 MP
# Price:  Discontinued
# Model:  Voice Xtreme V60 Price & Specs
# os:  Android OS, Jelly Bean 4.2
# cpu:  IPS QHD Touchscreen, 16M colors, Multitouch
# ram:  autofocus
# rom: 12 MP
# Price:  Discontinued
# Model:  Voice Xtreme V30 Price & Specs
# os:  Android OS, v4.2 (Jelly Bean)
# cpu:  IPS HQ Touchscreen, 16M colors, Multitouch
# ram:  autofocus
# rom: 8 MP
# Price:  Discontinued
# Model:  Voice Xtreme V40 Price & Specs
# os:  Android 4.2 Jelly Bean
# cpu:  IPS QHD Touchscreen, 16M colors, Multitouch
# ram:  full focus
# rom: 8 MP
# Price:  Discontinued
# Format Not Supported
# Model:  Voice Xtreme V75 Price & Specs
# os:  Android OS, Jelly Bean 4.2
# cpu:  QHD IPS capitative Touchscreen, 16k colors, Multitouch
# ram:  autofocus
# rom: 8 MP
# Price:  Discontinued
# Format Not Supported
# Format Not Supported
# The End
